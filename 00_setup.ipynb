# %% [markdown]
# # What is This?
# This is a *"Python Notebook"*, which splits up code and text into **separate `cells`**.

# %% [markdown]
# # Setting Up the Environment
# To Setup this workspace, create a **`Virtual Environment` (venv)**, so the packages to run this notebook can be installed
#
# In a terminal (`Terminal -> New Terminal` in *VSCode*), run
# **`python -m venv .venv`**
#
# Then, once you run code in a notebook, it will ask you to **Select a Kernel**.
# Choose the `.venv` folder, and let it download packages if it asks.

# %% [markdown]
# # Using Notebooks
# The cell below is a *code cell*, where you can **edit the code** and run it.
# **To run Code Cells, Press the `Play Button` on the `Left` of a cell**.
# 🢇

# %%
print("notebook :]")

5 + 17 * 2
# Out:
# notebook :]
# 39
